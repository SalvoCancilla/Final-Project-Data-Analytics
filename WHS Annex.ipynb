# %%
import pandas as pd
import numpy as np

import seaborn as sns

# %%
df_raw=pd.read_excel("C:/Users/Lavoro/Desktop/WHS Annex.xlsx")
df=df_raw.copy()
df
# Out:
#                           Country Total Population (Male) (2020)  \
# 0                     Afghanistan                          19976
# 1                         Albania                           1465
# 2                         Algeria                          22154
# 3                         Andorra                              -
# 4                          Angola                          16261
# ..                            ...                            ...
# 199               European Region                         452591
# 200  Eastern Mediterranean Region                         374719
# 201        Western Pacific Region                         987323
# 202                           NaN                            NaN
# 203                        Global                        3911812
#
#     Total Population (Female) (2020)  Total Population (Both) (2020)  \
# 0                              18952                         38928.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 15 columns):
#  #   Column                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                   --------------  -----
#  0   Country                                                                                                  202 non-null    object
#  1   Total Population (Male) (2020)                                                                           202 non-null    object
#  2   Total Population (Female) (2020)                                                                         201 non-null    object
#  3   Total Population (Both) (2020)                                                                           201 non-null    float64
# ...
